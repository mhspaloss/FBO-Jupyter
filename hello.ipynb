# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
a = np.random.rand(100)
a
# Out:
# array([0.45291263, 0.52905254, 0.88145158, 0.8283877 , 0.1955556 ,
#        0.15748642, 0.13257136, 0.85953503, 0.97072662, 0.75059526,
#        0.90076026, 0.80206818, 0.96887153, 0.24509998, 0.58655313,
#        0.25485151, 0.08812845, 0.17967552, 0.55279701, 0.02508414,
#        0.24232315, 0.06599981, 0.62969873, 0.44286189, 0.42828771,
#        0.42888201, 0.32127674, 0.44221162, 0.82592069, 0.26232018,
#        0.70048917, 0.61274679, 0.68694074, 0.83783705, 0.396622  ,
#        0.01424879, 0.10096566, 0.33694979, 0.04641986, 0.67107935,
#        0.03197812, 0.88539871, 0.89775256, 0.01241086, 0.84693991,
#        0.16364201, 0.64315744, 0.39436153, 0.17985205, 0.6587267 ,
#        0.10747047, 0.62954511, 0.50545616, 0.4232886 , 0.74141692,
#        0.47724306, 0.27115327, 0.90490368, 0.89006512, 0.5350645 ,
#        0.71904269, 0.107884  , 0.7254307 , 0.30171441, 0.99607335,
#        0.5988779 , 0.90661005, 0.76904653, 0.93562224, 0.33305499,
# ...

# %%
s = pd.Series(a)
s
# Out:
# 0     0.452913
# 1     0.529053
# 2     0.881452
# 3     0.828388
# 4     0.195556
# 5     0.157486
# 6     0.132571
# 7     0.859535
# 8     0.970727
# 9     0.750595
# 10    0.900760
# 11    0.802068
# 12    0.968872
# 13    0.245100
# 14    0.586553
# 15    0.254852
# 16    0.088128
# 17    0.179676
# 18    0.552797
# 19    0.025084
# 20    0.242323
# 21    0.066000
# 22    0.629699
# 23    0.442862
# 24    0.428288
# 25    0.428882
# 26    0.321277
# 27    0.442212
# 28    0.825921
# 29    0.262320
#         ...
# 70    0.051354
# 71    0.194166
# 72    0.306046
# 73    0.388390
# 74    0.016281
# 75    0.605351
# 76    0.129458
# 77    0.378808
# 78    0.293606
# 79    0.163881
# 80    0.630217
# 81    0.215898
# 82    0.136668
# 83    0.429137
# 84    0.933563
# 85    0.257993
# 86    0.673053
# 87    0.038664
# 88    0.922414
# 89    0.926382
# 90    0.089666
# 91    0.014386
# 92    0.979766
# 93    0.822578
# 94    0.738143
# 95    0.357848
# 96    0.217356
# 97    0.022982
# ...

# %%
s.plot()
